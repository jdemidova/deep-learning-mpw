# %% [markdown]
# # Student group: "I'm Learning"
# - **Student 1: Iuliia Demidova** --> I
# - **Student 2: Maurice FitzGerald** --> m
# - **Student 3: Lucas Keller** --> Learning

# %% [markdown]
# # Abstract

# %% [markdown]
# # Simple Model

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# # Deeper Model

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# # The Deepest Model

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# # Overfit vs Underfit

# %% [markdown]
# # Regularisation

# %% [markdown]
# # Optimizers

# %% [markdown]
# # [DRAFT for optional objectives chosen]
